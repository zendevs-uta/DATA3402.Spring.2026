# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class counter:
    def __init__(self, max_val):
        self.val = 0
        self.max_val = max_val

    def increment(self):
        if self.val >= self.max_val:
            print("Error: cannot go past max.")
        else:
            self.val += 1

    def reset(self):
        self.val = 0

    def get_val(self):
        return self.val

# Code reference straight from Lecture 8
# Storing this here for personal reference, no real utility besides that

# class person:
#     def __init__(self, name):
#         self.name = name
#
#     def say_hello(self):
#         print("Hello, my name is " + self.name)
#
#
# # Example usage:
# # bob = person("Bob")
# # bob.say_hello()

# class student:
#     def __init__(self, name, id_number, year):
#         self.name = name
#         self.id_number = id_number
#         self.year = year
#         self.grades = list()
#
#     def add_grade(self, grade):
#         self.grades.append(grade)
#
#     def average_grade(self):
#         return sum(self.grades) / len(self.grades)

# class car:
#     def __init__(self, name="Unnamed", max_passengers=4):
#         self.__name = name
#         self.__n_passengers = 0
#         self.__max_passengers = max_passengers
#
#     def add_passenger(self, n=1):
#         self.__n_passengers += n
#         if self.__n_passengers > self.__max_passengers:
#             self.__n_passengers = self.__max_passengers
#             print("Car is full. Extra passengers cannot enter.")
#
#     def remove_passenger(self, n=1):
#         self.__n_passengers -= n
#         if self.__n_passengers < 0:
#             self.__n_passengers = 0

# %%
# Test cell to ensure functional use

#max value for the counter class
c = counter(3)
print("init val:", c.get_val())
c.increment()
print("incr val:",c.get_val())
c.increment()
print("incr val:",c.get_val())
c.increment()
print("incr val:",c.get_val())
c.increment() # This one shows error, it still prints the incr val but the function works
print("incr val:",c.get_val())

# as name implies, resetting counter val
c.reset()
print("reset test, should be 0:",c.get_val())
# Out:
# init val: 0
# incr val: 1
# incr val: 2
# incr val: 3
# Error: cannot go past max.
# incr val: 3
# reset test, should be 0: 0

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class counter:
    def __init__(self, max_val):
        self.__val = 0
        self.__max_val = max_val

    def increment(self):
        if self.__val >= self.__max_val:
            print("Error: cannot go past max.")
        else:
            self.__val += 1

    def reset(self):
        self.__val = 0

    # check current value
    def get_val(self):
        return self.__val

    # check maximum value
    def get_max(self):
        return self.__max_val

    # check if counter is at max
    def is_at_max(self):
        return self.__val == self.__max_val

# lecture 8 outlines how __ makes a class priv

# referenced code

# class car:
#     def __init__(self, name="Unnamed", max_passengers=4):
#         self.__name = name
#         self.__n_passengers = 0
#         self.__max_passengers = max_passengers
#
#     def add_passenger(self, n=1):
#         self.__n_passengers += n
#         if self.__n_passengers > self.__max_passengers:
#             self.__n_passengers = self.__max_passengers
#             print("Car is full. Extra passengers cannot enter.")
#
#     def remove_passenger(self, n=1):
#         self.__n_passengers -= n
#         if self.__n_passengers < 0:
#             self.__n_passengers = 0

# %%
c = counter(3)

# initial value check
print("init val:", c.get_val())
print("max val:", c.get_max())
print("is at max?:", c.is_at_max())


# increment testing
c.increment()
print("incr val:", c.get_val())
print("is at max?:", c.is_at_max())

c.increment()
print("incr val:", c.get_val())
print("is at max?:", c.is_at_max())

c.increment()
print("incr val:", c.get_val())
print("is at max?:", c.is_at_max())


# attempt to exceed max
c.increment()  # should show error, just hardcoding this one so it douesnt simply repeat incr val: 3 when pst max
print("after exceeding attempt:", c.get_val())
print("is at max?:", c.is_at_max())


# reset testing
c.reset()
print("reset test, should be @ 0:", c.get_val())
print("is at max after reset?:", c.is_at_max())

# testing the private access
print("Testing private access:")

try:
    print(c.__val)
except AttributeError:
    print("cannot access __val directly, it is private")

try:
    print(c.__max_val)
except AttributeError:
    print("cannot access __max_val directly, it is pirvate")
# Out:
# init val: 0
# max val: 3
# is at max?: False
# incr val: 1
# is at max?: False
# incr val: 2
# is at max?: False
# incr val: 3
# is at max?: True
# Error: cannot go past max.
# after exceeding attempt: 3
# is at max?: True
# reset test, should be @ 0: 0
# is at max after reset?: False
# Testing private access:
# cannot access __val directly, it is private
# cannot access __max_val directly, it is pirvate

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class rectangle:
    def __init__(self, l, w, x, y):
        self.__l = l
        self.__w = w
        self.__x = x
        self.__y = y

    # just l time w
    def area(self):
        return self.__l * self.__w

    # perimeter is just 2 multiplied by the sum of l and w
    def perim(self):
        return 2 * (self.__l + self.__w)

    # acecessors for l w x and y
    def get_l(self):
        return self.__l

    def get_w(self):
        return self.__w

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

# Still just referencing lecture 8 student/car code as above

# %%
# class test

# math functions, x and y just 0 0 for now
r = rectangle(5, 3, 0, 0)

print("length:", r.get_l())
print("width:", r.get_w())
print("corner x:", r.get_x())
print("corner y:", r.get_y())

# math test
print("area:", r.area())
print("perimeter:", r.perim())

# private data test
print("private access test")

try:
    print(r.__l)
except AttributeError:
    print("cannot access length directly (private)")
# Out:
# length: 5
# width: 3
# corner x: 0
# corner y: 0
# area: 15
# perimeter: 16
# private access test
# cannot access length directly (private)

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
import math
# this import is only being done for pi, ill note later where its used

class circ:
    def __init__(self, r, x, y):
        self.__r = r
        self.__x = x
        self.__y = y

    # area is just pi r squared
    def area(self):
        return math.pi * (self.__r ** 2)
        # above is the only place "math" is used, just using 3.14159 would be fine too

    # circumference, just using perim here again for consistency w other functions/classes
    # its just 2 pi r
    def perim(self):
        return 2 * math.pi * self.__r

    # accessors
    def get_r(self):
        return self.__r

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

# %%
# circle tests

c = circ(2, 0, 0)

print("radius:", c.get_r())
print("center x:", c.get_x())
print("center y:", c.get_y())

print("area:", c.area())
print("perimeter:", c.perim())


# private data test
print("private access test")

try:
    print(c.__r)
except AttributeError:
    print("cannot access length directly (private)")
# Out:
# radius: 2
# center x: 0
# center y: 0
# area: 12.566370614359172
# perimeter: 12.566370614359172
# private access test
# cannot access length directly (private)

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
# Lecture 9 base class implementation, below was the reference

# The lecture code included kwargs and name="" which isnt reallt relevant here yet
# will be useful when we implement canvas or something of the same vain
class shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y

    # virtual methods
    def area(self):
        raise NotImplementedError("area not implemented")

    def perim(self):
        raise NotImplementedError("perim not implemented")

    # shared accessors
    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class rectangle(shape):
    def __init__(self, l, w, x, y):
        # I wanted to know if there was a different way
        # I found super().__init__(x, y) works too, but im gonna stick with lecture style
        shape.__init__(self, x, y)
        self.__l = l
        self.__w = w

    def area(self):
        return self.__l * self.__w

    def perim(self):
        return 2 * (self.__l + self.__w)

    def get_l(self):
        return self.__l

    def get_w(self):
        return self.__w


class circle(shape):
    def __init__(self, r, x, y):
        # i kept forgetting self, makes the whole thing brick itself
        shape.__init__(self, x, y)
        self.__r = r
        self.__pi = math.pi

    def area(self):
        return self.__pi * self.__r ** 2

    def perim(self):
        return 2 * self.__pi * self.__r

    def get_r(self):
        return self.__r

# class Shape:
#     def __init__(self, name="", **kwargs):
#         self.name=name
#         self.kwargs=kwargs
#     
#     def paint(self, canvas): pass
#
# class Rectangle(Shape):
#     def __init__(self, x, y, w, h, **kwargs):
#         Shape.__init__(self, **kwargs)
#         self.x = x
#         self.y = y
#         self.w = w
#         self.h = h
#
#     def paint(self, canvas):
#         # overrides Shape.paint
# and so on

# %%
# question 5 test

r = rectangle(5, 3, 0, 0)
print("rect pos:", r.get_x(), r.get_y())
print("rect size:", r.get_l(), r.get_w())
print("rect area:", r.area())
print("rect perim:", r.perim())

c = circle(2, 1, 1)
print("\ncirc pos:", c.get_x(), c.get_y())
print("circ r:", c.get_r())
print("circ area:", c.area())
print("circ perim:", c.perim())

# base class check, expecting the NotImplementedError for both
print("\nbase class check")
s = shape(0, 0)
try:
    s.area()
except NotImplementedError:
    print("shape area not implemented")
try:
    s.perim()
except NotImplementedError:
    print("shape area not implemented")
# Out:
# rect pos: 0 0
# rect size: 5 3
# rect area: 15
# rect perim: 16
#
# circ pos: 1 1
# circ r: 2
# circ area: 12.566370614359172
# circ perim: 12.566370614359172
#
# base class check
# shape area not implemented
# shape area not implemented

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
# going into this with the assumption that shape will be passed into triangle

# cannot use b and h because it will not be analagous to the two prior shapes, perim and area are needed
class triangle(shape):
    def __init__(self, a, b, c, x, y):
        shape.__init__(self, x, y)
        self.__a = a
        self.__b = b
        self.__c = c

    # perimeter, just the 3 sides added together
    def perim(self):
        return self.__a + self.__b + self.__c

    # area
    # thisis using herons formula vs figuring out base and height, easiest bc we can directly
    # utliize a b and c w/o issue
    # formula is sqrt((s)(s - a)(s - b)(s - c))
    # s would be (a + b + c) over 2
    # I used chatGPT here, wasnt really sure what the easiest way to go ab this was but this is
    # significantly better than what i had prior
    def area(self):
        s = self.perim() / 2
        return (s * (s - self.__a) * (s - self.__b) * (s - self.__c)) ** 0.5

    # accessors
    def get_a(self):
        return self.__a

    def get_b(self):
        return self.__b

    def get_c(self):
        return self.__c

# referencing the same Lecture 9 code

# %%
# triangle test cell

# t = triange(a b c x y)
# with these dims perim is 12 and area is 6
t = triangle(3, 4, 5, 0, 0)

print("tri pos:", t.get_x(), t.get_y())
print("tri sides:", t.get_a(), t.get_b(), t.get_c())

print("tri perim:", t.perim())
print("tri area:", t.area())

# private access test
print("\nprivate access test")
try:
    print(t.__a)
except AttributeError:
    print("cannot access side a directly (private)")
# same idea should apply to b and c so no point in repeating
# Out:
# tri pos: 0 0
# tri sides: 3 4 5
# tri perim: 12
# tri area: 6.0
#
# private access test
# cannot access side a directly (private)

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
# overall code w/ the point functionality
# paramaterizatinon for the shapes
# Essentially, just tracing the boundary/perimeter and gathering 16 points along its path

# redundnat, but adding math since overall code is now shaping up again
import math

class shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y

    # "virtual" methods
    def area(self):
        raise NotImplementedError("area not implemented")

    def perim(self):
        raise NotImplementedError("perim not implemented")

    def points(self, n=16):
        raise NotImplementedError("points not implemented")

    # accessors
    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class rectangle(shape):
    def __init__(self, l, w, x, y):
        shape.__init__(self, x, y)
        self.__l = l
        self.__w = w

    def area(self):
        return self.__l * self.__w

    def perim(self):
        return 2 * (self.__l + self.__w)

    # point identfication/parameterization
    def points(self, n=16):
        # returns n points around the perimeter
        n = min(16, max(1, int(n)))
        # ensures n is an integer and at least one point
        # min ensures there are 16 points at most
        # essentially 1 <= n <= 16
        pts = []

        # x0 and y0 are essentiakky just where the shape begins
        x0 = self.get_x()
        y0 = self.get_y()
        l = self.__l
        w = self.__w

        # split points across 4 edges, pts per edge of rectange
        # sets up next section for stepping thru the 4 sides
        side = max(1, n // 4)

        # paramaterization section
        
        # stepping through the bottom side
        for i in range(side):
            t = i / side
            pts.append((x0 + t * l, y0))

        # stepping thru the right side
        for i in range(side):
            t = i / side
            pts.append((x0 + l, y0 + t * w))

        # topside
        for i in range(side):
            t = i / side
            pts.append((x0 + l - t * l, y0 + w))

        # leftside
        for i in range(side):
            t = i / side
            pts.append((x0, y0 + w - t * w))

        return pts[:n]

    # accessors
    def get_l(self):
        return self.__l

    def get_w(self):
        return self.__w


class circle(shape):
    def __init__(self, r, x, y):
        shape.__init__(self, x, y)
        self.__r = r
        self.__pi = math.pi

    def area(self):
        return self.__pi * (self.__r ** 2)

    def perim(self):
        return 2 * self.__pi * self.__r

    def points(self, n=16):
        # returns up to n oints around the circumference, essentially uses the origin
        # and angles from the origin to segment the circle
        n = min(16, max(1, int(n)))
        pts = []
        # values for the center of the circle, hence "center x and center y"
        center_x = self.get_x()
        center_y = self.get_y()
        r = self.__r

        for i in range(n):
            # t is the circle divided into 16 segments
            t = 2 * math.pi * i / n
            # before, only utilized pi but cosine and sin are necessary in this implementation
            pts.append((center_x + r * math.cos(t), center_y + r * math.sin(t)))

        return pts

    # accessor
    def get_r(self):
        return self.__r


class triangle(shape):
    # x and y points are at the first vertex
    def __init__(self, a, b, c, x, y):
        shape.__init__(self, x, y)
        self.__a = a
        self.__b = b
        self.__c = c

    def perim(self):
        return self.__a + self.__b + self.__c

    def area(self):
        s = self.perim() / 2
        return (s * (s - self.__a) * (s - self.__b) * (s - self.__c)) ** 0.5

    # Was at a loss about how to go about this one, used ChatGPT to help walkthrough the process to ensure it came out right
    # I only changed variable names, but the logic remains the same as GPT for the most part

    # ChatGPT comment below
    # stores 3 sides a,b,c and a reference point (x,y) for vertex 1
    # layout assumption:
    #   v1 = (x,y)
    #   v2 = (x+a, y)
    #   v3 computed so that |v1-v3|=b and |v2-v3|=c
    # def points(self, n=16):
    #     n = min(16, max(1, int(n)))
    #    # same as before like in rectangle
    #    
    #    pts = []
    #
    #    # same formatting as before now
    #    x1 = self.get_x()
    #    y1 = self.get_y()
    #    a = self.__a
    #    b = self.__b
    #    c = self.__c
    #
    #    # Chat GPT generation below, this section below is essentially just a validity check to ensure the
    #    # triangle is "valid"
    #    if a + b <= c or a + c <= b or b + c <= a or a <= 0 or b <= 0 or c <= 0:
    #        return pts  # return empty list if the triangle is invalid
    #
    #    # v2 on x-axis from v1 (GPT comment)
    #    x2 = x1 + a
    #    y2 = y1
    #    # essentially, going from vertice to vertice
    #
    #    # compute v3 using intersection math
    #    # x3 = (b^2 + a^2 - c^2) / (2a) from v1, then shift by x1
    #    x3 = x1 + (b*b + a*a - c*c) / (2*a)
    #    # y offset from v1: sqrt(b^2 - (x3-x1)^2)
    #    y_sq = b*b - (x3 - x1) ** 2
    #    y3 = y1 + (y_sq ** 0.5 if y_sq > 0 else 0.0)
    #    # Frankly, a little lost here
    #
    #    v = [(x1, y1), (x2, y2), (x3, y3)]
    #
    #    # split points across the 3 edges of the triangle
    #    k = max(1, n // 3)
    #
    #    for i in range(3):
    #        xA, yA = v[i]
    #        xB, yB = v[(i + 1) % 3]
    #        for j in range(k):
    #            t = j / k
    #            pts.append((xA + t * (xB - xA), yA + t * (yB - yA)))
    #
    #    return pts[:n]

    # Re-doint the points function, leaving old documentation and taking whats useful and repeating below

    # def points(self, n=16):
    #     n = min(16, max(1, int(n)))
    #     pts = []
    # 
    #     x1 = self.get_x()
    #     y1 = self.get_y()
    # 
    #     a = self.__a
    #     b = self.__b
    #     c = self.__c
    # 
    #     # Validity check
    #     if a + b <= c or a + c <= b or b + c <= a:
    #         return pts
    # 
    #     # second vertex along x direction
    #     x2 = x1 + a
    #     y2 = y1
    # 
    #     # third vertex using triangle geometry
    #     x3 = x1 + (b*b + a*a - c*c) / (2*a)
    #     y3 = y1 + (b*b - (x3 - x1)**2) ** 0.5
    # 
    #     # helper functoin
    #     def line_points(xA, yA, xB, yB, count):
    #             out = []
    #             for i in range(count):
    #                 t = i / count
    #                 x = xA + t * (xB - xA)
    #                 y = yA + t * (yB - yA)
    #                 out.append((x, y))
    #             return out
    # 
    #     per_edge = max(1, n // 3)
    # 
    #     pts += line_points(x1, y1, x2, y2, per_edge)
    #      pts += line_points(x2, y2, x3, y3, per_edge)
    #     pts += line_points(x3, y3, x1, y1, per_edge)
    #  
    #     return pts[:n]

    def points(self, n=16):
        n = min(16, max(1, int(n)))
        pts = []
    
        x1 = self.get_x()
        y1 = self.get_y()
    
        a = self.__a
        b = self.__b
        c = self.__c
    
        # validity check (basic)
        if a <= 0 or b <= 0 or c <= 0:
            return pts
        if a + b <= c or a + c <= b or b + c <= a:
            return pts
    
        # v2
        x2 = x1 + a
        y2 = y1
    
        # v3
        x3 = x1 + (b*b + a*a - c*c) / (2*a)
        y_sq = b*b - (x3 - x1)**2
        if y_sq < 0:
            return pts
        y3 = y1 + (y_sq ** 0.5)
    
        def line_points(xA, yA, xB, yB, count):
            out = []
            for i in range(count):
                t = i / count
                out.append((xA + t * (xB - xA), yA + t * (yB - yA)))
            return out
    
        base = n // 3
        rem = n % 3
    
        n1 = base + (1 if rem > 0 else 0)
        n2 = base + (1 if rem > 1 else 0)
        n3 = base
    
        pts += line_points(x1, y1, x2, y2, max(1, n1))
        pts += line_points(x2, y2, x3, y3, max(1, n2))
        pts += line_points(x3, y3, x1, y1, max(1, n3))
    
        return pts[:n]
    
    # accessors
    def get_a(self):
        return self.__a

    def get_b(self):
        return self.__b

    def get_c(self):
        return self.__c

# sampling boundary points isnt something that can be pretty much ripped from lecture 9, so not including reference here
# kinda like paint()?

# %%
# much more concise test section

r = rectangle(5, 3, 0, 0)
c = circle(2, 1, 1)
t = triangle(3, 4, 5, 0, 0)

# summary line (same as before)
print("rect:", r.area(), r.perim(), len(r.points()))
print("circ:", c.area(), c.perim(), len(c.points()))
print("tri :", t.area(), t.perim(), len(t.points()))

# full point lists
print("\nrect pts:", r.points())
print("\ncirc pts:", c.points())
print("\ntri  pts:", t.points())

# base class virtual check
try:
    shape(0, 0).points()
except NotImplementedError:
    print("\nshape points: NotImplemented (ok)")
# Out:
# rect: 15 16 16
# circ: 12.566370614359172 12.566370614359172 16
# tri : 6.0 12 16
#
# rect pts: [(0.0, 0), (1.25, 0), (2.5, 0), (3.75, 0), (5, 0.0), (5, 0.75), (5, 1.5), (5, 2.25), (5.0, 3), (3.75, 3), (2.5, 3), (1.25, 3), (0, 3.0), (0, 2.25), (0, 1.5), (0, 0.75)]
#
# circ pts: [(3.0, 1.0), (2.8477590650225735, 1.7653668647301797), (2.414213562373095, 2.414213562373095), (1.7653668647301797, 2.8477590650225735), (1.0000000000000002, 3.0), (0.23463313526982055, 2.8477590650225735), (-0.4142135623730949, 2.414213562373095), (-0.8477590650225735, 1.7653668647301797), (-1.0, 1.0000000000000002), (-0.8477590650225737, 0.23463313526982066), (-0.41421356237309537, -0.4142135623730949), (0.23463313526981933, -0.847759065022573), (0.9999999999999997, -1.0), (1.7653668647301801, -0.8477590650225733), (2.414213562373095, -0.41421356237309537), (2.847759065022573, 0.23463313526981922)]
#
# ...

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
# overall code w/ the point functionality
# paramaterizatinon for the shapes
# Essentially, just tracing the boundary/perimeter and gathering 16 points along its path

import math

class shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y

    # "virtual" methods
    def area(self):
        raise NotImplementedError("area not implemented")

    def perim(self):
        raise NotImplementedError("perim not implemented")

    def points(self, n=16):
        raise NotImplementedError("points not implemented")

    # inside check
    def inside(self, x, y):
        raise NotImplementedError("inside not implemented")

    # accessors
    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class rectangle(shape):
    def __init__(self, l, w, x, y):
        shape.__init__(self, x, y)
        self.__l = l
        self.__w = w

    def area(self):
        return self.__l * self.__w

    def perim(self):
        return 2 * (self.__l + self.__w)

    # point identfication/parameterization
    def points(self, n=16):
        n = min(16, max(1, int(n)))
        pts = []

        x0 = self.get_x()
        y0 = self.get_y()
        l = self.__l
        w = self.__w

        side = max(1, n // 4)

        # bottom
        for i in range(side):
            t = i / side
            pts.append((x0 + t * l, y0))

        # right
        for i in range(side):
            t = i / side
            pts.append((x0 + l, y0 + t * w))

        # top
        for i in range(side):
            t = i / side
            pts.append((x0 + l - t * l, y0 + w))

        # left
        for i in range(side):
            t = i / side
            pts.append((x0, y0 + w - t * w))

        return pts[:n]

    # checking inside for rectangle
    def inside(self, x, y):
        x0 = self.get_x()
        y0 = self.get_y()

        # basic logic for checking bounds
        if x < x0:
            return False
        if x > x0 + self.__l:
            return False
        if y < y0:
            return False
        if y > y0 + self.__w:
            return False

        return True

    # accessors
    def get_l(self):
        return self.__l

    def get_w(self):
        return self.__w


class circle(shape):
    def __init__(self, r, x, y):
        shape.__init__(self, x, y)
        self.__r = r
        self.__pi = math.pi

    def area(self):
        return self.__pi * (self.__r ** 2)

    def perim(self):
        return 2 * self.__pi * self.__r

    def points(self, n=16):
        n = min(16, max(1, int(n)))
        pts = []

        center_x = self.get_x()
        center_y = self.get_y()
        r = self.__r

        for i in range(n):
            t = 2 * math.pi * i / n
            pts.append((center_x + r * math.cos(t), center_y + r * math.sin(t)))

        return pts

    # checking inside for circle
    def inside(self, x, y):
        center_x = self.get_x()
        center_y = self.get_y()

        # 
        dx = x - center_x
        dy = y - center_y
    
        dist = math.sqrt(dx*dx + dy*dy)
        return dist <= self.__r

    # accessor
    def get_r(self):
        return self.__r


class triangle(shape):
    # x and y points are at the first vertex
    def __init__(self, a, b, c, x, y):
        shape.__init__(self, x, y)
        self.__a = a
        self.__b = b
        self.__c = c

    def perim(self):
        return self.__a + self.__b + self.__c

    def area(self):
        s = self.perim() / 2
        return (s * (s - self.__a) * (s - self.__b) * (s - self.__c)) ** 0.5

    def points(self, n=16):
        n = min(16, max(1, int(n)))
        pts = []

        x1 = self.get_x()
        y1 = self.get_y()

        a = self.__a
        b = self.__b
        c = self.__c

        # validity check (basic)
        if a <= 0 or b <= 0 or c <= 0:
            return pts
        if a + b <= c or a + c <= b or b + c <= a:
            return pts

        # v2
        x2 = x1 + a
        y2 = y1

        # v3
        x3 = x1 + (b*b + a*a - c*c) / (2*a)
        y_sq = b*b - (x3 - x1)**2
        if y_sq < 0:
            return pts
        y3 = y1 + (y_sq ** 0.5)

        def line_points(xA, yA, xB, yB, count):
            out = []
            for i in range(count):
                t = i / count
                out.append((xA + t * (xB - xA), yA + t * (yB - yA)))
            return out

        base = n // 3
        rem = n % 3

        n1 = base + (1 if rem > 0 else 0)
        n2 = base + (1 if rem > 1 else 0)
        n3 = base

        pts += line_points(x1, y1, x2, y2, max(1, n1))
        pts += line_points(x2, y2, x3, y3, max(1, n2))
        pts += line_points(x3, y3, x1, y1, max(1, n3))

        return pts[:n]

    # inside check for triangle w/area method
    def inside(self, x, y):
        x1 = self.get_x()
        y1 = self.get_y()

        a = self.__a
        b = self.__b
        c = self.__c

        # invalid triangle check
        if a <= 0 or b <= 0 or c <= 0:
            return False
        if a + b <= c or a + c <= b or b + c <= a:
            return False

        # v2
        x2 = x1 + a
        y2 = y1

        # v3
        x3 = x1 + (b*b + a*a - c*c) / (2*a)
        y_sq = b*b - (x3 - x1)**2
        if y_sq < 0:
            return False
        y3 = y1 + (y_sq ** 0.5)

        # separated functions like the prior point generation for triangle
        def tri_area(xa, ya, xb, yb, xc, yc):
            return abs(xa*(yb-yc) + xb*(yc-ya) + xc*(ya-yb)) / 2

        full = tri_area(x1, y1, x2, y2, x3, y3)
        a1 = tri_area(x, y, x2, y2, x3, y3)
        a2 = tri_area(x1, y1, x, y, x3, y3)
        a3 = tri_area(x1, y1, x2, y2, x, y)

        return abs((a1 + a2 + a3) - full) < 1e-6

    # accessors
    def get_a(self):
        return self.__a

    def get_b(self):
        return self.__b

    def get_c(self):
        return self.__c

# used this
# https://www.geeksforgeeks.org/dsa/check-whether-a-given-point-lies-inside-a-triangle-or-not/

# %%
# simple inside() test, basic but works well to express new functions

r = rectangle(5, 3, 0, 0)
c = circle(2, 1, 1)
t = triangle(3, 4, 5, 0, 0)

print("rectangle inside:", r.inside(2, 1), r.inside(10, 10))
print("circle inside:", c.inside(1, 1), c.inside(10, 10))
print("triangle inside:", t.inside(1, 1), t.inside(10, 10))
# Out:
# rectangle inside: True False
# circle inside: True False
# triangle inside: True False

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
# chefs kiss for only having to go into the shape class

# overall code w/ the point functionality
# paramaterizatinon for the shapes
# Essentially, just tracing the boundary/perimeter and gathering 16 points along its path

import math

class shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y

    # "virtual" methods
    def area(self):
        raise NotImplementedError("area not implemented")

    def perim(self):
        raise NotImplementedError("perim not implemented")

    def points(self, n=16):
        raise NotImplementedError("points not implemented")

    # inside check
    def inside(self, x, y):
        raise NotImplementedError("inside not implemented")

    # accessors
    def get_x(self):
        return self.__x
                        
    def get_y(self):
        return self.__y

    def overlap(self, other_shape):
        # idea is too check boundary points from a primary shape and the if
        # it is inside the other shape, and vice versa
        # in the instance they do, then shapes overlap and return true
        
        # Shape boundary points of primary
        my_points = self.points()
        for point in my_points:
            x_coord = point[0]
            y_coord = point[1]
    
            if other_shape.inside(x_coord, y_coord):
                return True
    
        # Second shape boundary checking
        other_points = other_shape.points()
        for point in other_points:
            x_coord = point[0]
            y_coord = point[1]
    
            if self.inside(x_coord, y_coord):
                return True #overlap found
    
        # no overlap found
        return False
            


class rectangle(shape):
    def __init__(self, l, w, x, y):
        shape.__init__(self, x, y)
        self.__l = l
        self.__w = w

    def area(self):
        return self.__l * self.__w
    
    def perim(self):
        return 2 * (self.__l + self.__w)

    # point identfication/parameterization
    def points(self, n=16):
        n = min(16, max(1, int(n)))
        pts = []

        x0 = self.get_x()
        y0 = self.get_y()
        l = self.__l
        w = self.__w

        side = max(1, n // 4)

        # bottom
        for i in range(side):
            t = i / side
            pts.append((x0 + t * l, y0))

        # right
        for i in range(side):
            t = i / side
            pts.append((x0 + l, y0 + t * w))

        # top
        for i in range(side):
            t = i / side
            pts.append((x0 + l - t * l, y0 + w))

        # left
        for i in range(side):
            t = i / side
            pts.append((x0, y0 + w - t * w))

        return pts[:n]

    # checking inside for rectangle
    def inside(self, x, y):
        x0 = self.get_x()
        y0 = self.get_y()

        # basic logic for checking bounds
        if x < x0:
            return False
        if x > x0 + self.__l:
            return False
        if y < y0:
            return False
        if y > y0 + self.__w:
            return False

        return True

    # accessors
    def get_l(self):
        return self.__l

    def get_w(self):
        return self.__w


class circle(shape):
    def __init__(self, r, x, y):
        shape.__init__(self, x, y)
        self.__r = r
        self.__pi = math.pi

    def area(self):
        return self.__pi * (self.__r ** 2)

    def perim(self):
        return 2 * self.__pi * self.__r

    def points(self, n=16):
        n = min(16, max(1, int(n)))
        pts = []

        center_x = self.get_x()
        center_y = self.get_y()
        r = self.__r

        for i in range(n):
            t = 2 * math.pi * i / n
            pts.append((center_x + r * math.cos(t), center_y + r * math.sin(t)))

        return pts

    # checking inside for circle
    def inside(self, x, y):
        center_x = self.get_x()
        center_y = self.get_y()

        # 
        dx = x - center_x
        dy = y - center_y
    
        dist = math.sqrt(dx*dx + dy*dy)
        return dist <= self.__r

    # accessor
    def get_r(self):
        return self.__r


class triangle(shape):
    # x and y points are at the first vertex
    def __init__(self, a, b, c, x, y):
        shape.__init__(self, x, y)
        self.__a = a
        self.__b = b
        self.__c = c

    def perim(self):
        return self.__a + self.__b + self.__c

    def area(self):
        s = self.perim() / 2
        return (s * (s - self.__a) * (s - self.__b) * (s - self.__c)) ** 0.5

    def points(self, n=16):
        n = min(16, max(1, int(n)))
        pts = []

        x1 = self.get_x()
        y1 = self.get_y()

        a = self.__a
        b = self.__b
        c = self.__c

        # validity check (basic)
        if a <= 0 or b <= 0 or c <= 0:
            return pts
        if a + b <= c or a + c <= b or b + c <= a:
            return pts

        # v2
        x2 = x1 + a
        y2 = y1

        # v3
        x3 = x1 + (b*b + a*a - c*c) / (2*a)
        y_sq = b*b - (x3 - x1)**2
        if y_sq < 0:
            return pts
        y3 = y1 + (y_sq ** 0.5)

        def line_points(xA, yA, xB, yB, count):
            out = []
            for i in range(count):
                t = i / count
                out.append((xA + t * (xB - xA), yA + t * (yB - yA)))
            return out

        base = n // 3
        rem = n % 3

        n1 = base + (1 if rem > 0 else 0)
        n2 = base + (1 if rem > 1 else 0)
        n3 = base

        pts += line_points(x1, y1, x2, y2, max(1, n1))
        pts += line_points(x2, y2, x3, y3, max(1, n2))
        pts += line_points(x3, y3, x1, y1, max(1, n3))

        return pts[:n]

    # inside check for triangle w/area method
    def inside(self, x, y):
        x1 = self.get_x()
        y1 = self.get_y()

        a = self.__a
        b = self.__b
        c = self.__c

        # invalid triangle check
        if a <= 0 or b <= 0 or c <= 0:
            return False
        if a + b <= c or a + c <= b or b + c <= a:
            return False

        # v2
        x2 = x1 + a
        y2 = y1

        # v3
        x3 = x1 + (b*b + a*a - c*c) / (2*a)
        y_sq = b*b - (x3 - x1)**2
        if y_sq < 0:
            return False
        y3 = y1 + (y_sq ** 0.5)

        # separated functions like the prior point generation for triangle
        def tri_area(xa, ya, xb, yb, xc, yc):
            return abs(xa*(yb-yc) + xb*(yc-ya) + xc*(ya-yb)) / 2

        full = tri_area(x1, y1, x2, y2, x3, y3)
        a1 = tri_area(x, y, x2, y2, x3, y3)
        a2 = tri_area(x1, y1, x, y, x3, y3)
        a3 = tri_area(x1, y1, x2, y2, x, y)

        return abs((a1 + a2 + a3) - full) < 1e-6

    # accessors
    def get_a(self):
        return self.__a

    def get_b(self):
        return self.__b

    def get_c(self):
        return self.__c

# %%
r1 = rectangle(5, 3, 0, 0)
r2 = rectangle(2, 2, 4, 2)
r3 = rectangle(2, 2, 10, 10)

c1 = circle(2, 1, 1)
c2 = circle(1, 10, 10) 

t1 = triangle(3, 4, 5, 0, 0)

print("r1 vs r2:", r1.overlap(r2))
print("r1 vs r3:", r1.overlap(r3))
print("r1 vs c1:", r1.overlap(c1))
print("c1 vs c2:", c1.overlap(c2))
print("t1 vs r1:", t1.overlap(r1))

# true if overlaps, false if there is no overlap
# Out:
# r1 vs r2: True
# r1 vs r3: False
# r1 vs c1: True
# c1 vs c2: False
# t1 vs r1: True

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
# This is somewhat redundant, but below is all the code that is within the paint.py file. No need to run the code given here,
# just for my own sake.

# paint.py module
import math

#lecture stuff

class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        # Empty canvas is a matrix with element being the "space" character
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        self.data[row][col] = char

    def get_pixel(self, row, col):
        return self.data[row][col]
    
    def clear_canvas(self):
        self.data = [[' '] * self.width for i in range(self.height)]
    
    def v_line(self, x, y, w, **kargs):
        for i in range(x,x+w):
            self.set_pixel(i,y, **kargs)

    def h_line(self, x, y, h, **kargs):
        for i in range(y,y+h):
            self.set_pixel(x,i, **kargs)
            
    def line(self, x1, y1, x2, y2, **kargs):
        slope = (y2-y1) / (x2-x1)
        for y in range(y1,y2):
            x= int(slope * y)
            self.set_pixel(x,y, **kargs)
            
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))


# my stuff

class shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y

    # "virtual" methods
    def area(self):
        raise NotImplementedError("area not implemented")

    def perim(self):
        raise NotImplementedError("perim not implemented")

    def points(self, n=16):
        raise NotImplementedError("points not implemented")

    # inside check
    def inside(self, x, y):
        raise NotImplementedError("inside not implemented")

    # Q10: paint method (virtual)
    def paint(self, canvas):
        raise NotImplementedError("paint not implemented")

    # accessors
    def get_x(self):
        return self.__x
                        
    def get_y(self):
        return self.__y

    def overlap(self, other_shape):
        # idea is too check boundary points from a primary shape and the if
        # it is inside the other shape, and vice versa
        # in the instance they do, then shapes overlap and return true
        
        # Shape boundary points of primary
        my_points = self.points()
        for point in my_points:
            x_coord = point[0]
            y_coord = point[1]
    
            if other_shape.inside(x_coord, y_coord):
                return True
    
        # Second shape boundary checking
        other_points = other_shape.points()
        for point in other_points:
            x_coord = point[0]
            y_coord = point[1]
    
            if self.inside(x_coord, y_coord):
                return True #overlap found
    
        # no overlap found
        return False
            


class rectangle(shape):
    def __init__(self, l, w, x, y):
        shape.__init__(self, x, y)
        self.__l = l
        self.__w = w

    def area(self):
        return self.__l * self.__w
    
    def perim(self):
        return 2 * (self.__l + self.__w)

    # point identfication/parameterization
    def points(self, n=16):
        n = min(16, max(1, int(n)))
        pts = []

        x0 = self.get_x()
        y0 = self.get_y()
        l = self.__l
        w = self.__w

        side = max(1, n // 4)

        # bottom
        for i in range(side):
            t = i / side
            pts.append((x0 + t * l, y0))

        # right
        for i in range(side):
            t = i / side
            pts.append((x0 + l, y0 + t * w))

        # top
        for i in range(side):
            t = i / side
            pts.append((x0 + l - t * l, y0 + w))

        # left
        for i in range(side):
            t = i / side
            pts.append((x0, y0 + w - t * w))

        return pts[:n]

    # checking inside for rectangle
    def inside(self, x, y):
        x0 = self.get_x()
        y0 = self.get_y()

        # basic logic for checking bounds
        if x < x0:
            return False
        if x > x0 + self.__l:
            return False
        if y < y0:
            return False
        if y > y0 + self.__w:
            return False

        return True

    def paint(self, canvas):
        x0 = int(self.get_x())
        y0 = int(self.get_y())
        l = int(self.__l)
        w = int(self.__w)

        canvas.v_line(x0, y0, l + 1)
        canvas.v_line(x0, y0 + w, l + 1)
        canvas.h_line(x0, y0, w + 1)
        canvas.h_line(x0 + l, y0, w + 1)

    # accessors
    def get_l(self):
        return self.__l

    def get_w(self):
        return self.__w


class circle(shape):
    def __init__(self, r, x, y):
        shape.__init__(self, x, y)
        self.__r = r
        self.__pi = math.pi

    def area(self):
        return self.__pi * (self.__r ** 2)

    def perim(self):
        return 2 * self.__pi * self.__r

    def points(self, n=16):
        n = min(16, max(1, int(n)))
        pts = []

        center_x = self.get_x()
        center_y = self.get_y()
        r = self.__r

        for i in range(n):
            t = 2 * math.pi * i / n
            pts.append((center_x + r * math.cos(t), center_y + r * math.sin(t)))

        return pts

    # checking inside for circle
    def inside(self, x, y):
        center_x = self.get_x()
        center_y = self.get_y()
    
        dx = x - center_x
        dy = y - center_y
    
        dist = math.sqrt(dx*dx + dy*dy)
        return dist <= self.__r

    # paint circle using sampled perimeter points
    def paint(self, canvas):
        pts = self.points(16)
        for p in pts:
            canvas.set_pixel(int(p[0]), int(p[1]))

    # accessor
    def get_r(self):
        return self.__r


class triangle(shape):
    # x and y points are at the first vertex
    def __init__(self, a, b, c, x, y):
        shape.__init__(self, x, y)
        self.__a = a
        self.__b = b
        self.__c = c

    def perim(self):
        return self.__a + self.__b + self.__c

    def area(self):
        s = self.perim() / 2
        return (s * (s - self.__a) * (s - self.__b) * (s - self.__c)) ** 0.5

    def points(self, n=16):
        n = min(16, max(1, int(n)))
        pts = []

        x1 = self.get_x()
        y1 = self.get_y()

        a = self.__a
        b = self.__b
        c = self.__c

        # validity check (basic)
        if a <= 0 or b <= 0 or c <= 0:
            return pts
        if a + b <= c or a + c <= b or b + c <= a:
            return pts

        # v2
        x2 = x1 + a
        y2 = y1

        # v3
        x3 = x1 + (b*b + a*a - c*c) / (2*a)
        y_sq = b*b - (x3 - x1)**2
        if y_sq < 0:
            return pts
        y3 = y1 + (y_sq ** 0.5)

        def line_points(xA, yA, xB, yB, count):
            out = []
            for i in range(count):
                t = i / count
                out.append((xA + t * (xB - xA), yA + t * (yB - yA)))
            return out

        base = n // 3
        rem = n % 3

        n1 = base + (1 if rem > 0 else 0)
        n2 = base + (1 if rem > 1 else 0)
        n3 = base

        pts += line_points(x1, y1, x2, y2, max(1, n1))
        pts += line_points(x2, y2, x3, y3, max(1, n2))
        pts += line_points(x3, y3, x1, y1, max(1, n3))

        return pts[:n]

    # inside check for triangle w/area method
    def inside(self, x, y):
        x1 = self.get_x()
        y1 = self.get_y()

        a = self.__a
        b = self.__b
        c = self.__c

        # invalid triangle check
        if a <= 0 or b <= 0 or c <= 0:
            return False
        if a + b <= c or a + c <= b or b + c <= a:
            return False

        # v2
        x2 = x1 + a
        y2 = y1

        # v3
        x3 = x1 + (b*b + a*a - c*c) / (2*a)
        y_sq = b*b - (x3 - x1)**2
        if y_sq < 0:
            return False
        y3 = y1 + (y_sq ** 0.5)

        def tri_area(xa, ya, xb, yb, xc, yc):
            return abs(xa*(yb-yc) + xb*(yc-ya) + xc*(ya-yb)) / 2

        full = tri_area(x1, y1, x2, y2, x3, y3)
        a1 = tri_area(x, y, x2, y2, x3, y3)
        a2 = tri_area(x1, y1, x, y, x3, y3)
        a3 = tri_area(x1, y1, x2, y2, x, y)

        return abs((a1 + a2 + a3) - full) < 1e-6

    # paint triangle by drawing edges using Canvas.line()
    def paint(self, canvas):
        x1 = self.get_x()
        y1 = self.get_y()

        a = self.__a
        b = self.__b
        c = self.__c

        # validity check
        if a <= 0 or b <= 0 or c <= 0:
            return
        if a + b <= c or a + c <= b or b + c <= a:
            return

        x2 = x1 + a
        y2 = y1

        x3 = x1 + (b*b + a*a - c*c) / (2*a)
        y_sq = b*b - (x3 - x1)**2
        if y_sq < 0:
            return
        y3 = y1 + (y_sq ** 0.5)

        canvas.line(int(x1), int(y1), int(x2), int(y2))
        canvas.line(int(x2), int(y2), int(x3), int(y3))
        canvas.line(int(x3), int(y3), int(x1), int(y1))

    # accessors
    def get_a(self):
        return self.__a

    def get_b(self):
        return self.__b

    def get_c(self):
        return self.__c 


# CompoundShape class
class CompoundShape(shape):
    def __init__(self, shapes):
        shape.__init__(self, 0, 0)
        self.shapes = shapes

    def paint(self, canvas):
        for s in self.shapes:
            s.paint(canvas)

# So I had ChatGPT go through the code and re-examine anything that could go wrong
# It noted that def paint for triangle could potentially fail due to Canvas.line()
# in line(), x2 != x1 (or it will divide by zero)
# y2 > y1 (because it loops for y in range(y1, y2))

# So triangle edges can fail if:
# a side is vertical (x1 == x2)
# the line goes “backwards” (y2 < y1)
# y values are floats and range() breaks

# Below was the generated function which should aleviate the issue

# %%
# rought test 
cv = Canvas(60, 20)

r = rectangle(10, 5, 2, 2)
c = circle(4, 10, 30)
t = triangle(8, 7, 5, 12, 5)

combo = CompoundShape([r, c, t])
combo.paint(cv)

cv.display()
# Out:
#
#
#   ******
#   *    *
#   *    *
#   *    *
#   *    *                    * **
#   *    *                   *    *
#   *    *                  *      *
#   *    *
#   *    **                 *       *
#   *    *                  *      *
#   ******                   *    *
#                             *  *
#      *                        *

# %%
# paint.py module
import math

#lecture stuff

class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        # Empty canvas is a matrix with element being the "space" character
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        self.data[row][col] = char

    def get_pixel(self, row, col):
        return self.data[row][col]
    
    def clear_canvas(self):
        self.data = [[' '] * self.width for i in range(self.height)]
    
    def v_line(self, x, y, w, **kargs):
        for i in range(x,x+w):
            self.set_pixel(i,y, **kargs)

    def h_line(self, x, y, h, **kargs):
        for i in range(y,y+h):
            self.set_pixel(x,i, **kargs)
            
    def line(self, x1, y1, x2, y2, **kargs):
        slope = (y2-y1) / (x2-x1)
        for y in range(y1,y2):
            x= int(slope * y)
            self.set_pixel(x,y, **kargs)
            
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))


# my stuff

class shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y

    # "virtual" methods
    def area(self):
        raise NotImplementedError("area not implemented")

    def perim(self):
        raise NotImplementedError("perim not implemented")

    def points(self, n=16):
        raise NotImplementedError("points not implemented")

    # inside check
    def inside(self, x, y):
        raise NotImplementedError("inside not implemented")

    # Q10: paint method (virtual)
    def paint(self, canvas):
        raise NotImplementedError("paint not implemented")

    # accessors
    def get_x(self):
        return self.__x
                        
    def get_y(self):
        return self.__y

    def overlap(self, other_shape):
        # idea is too check boundary points from a primary shape and the if
        # it is inside the other shape, and vice versa
        # in the instance they do, then shapes overlap and return true
        
        # Shape boundary points of primary
        my_points = self.points()
        for point in my_points:
            x_coord = point[0]
            y_coord = point[1]
    
            if other_shape.inside(x_coord, y_coord):
                return True
    
        # Second shape boundary checking
        other_points = other_shape.points()
        for point in other_points:
            x_coord = point[0]
            y_coord = point[1]
    
            if self.inside(x_coord, y_coord):
                return True #overlap found
    
        # no overlap found
        return False
            


class rectangle(shape):
    def __init__(self, l, w, x, y):
        shape.__init__(self, x, y)
        self.__l = l
        self.__w = w

    def area(self):
        return self.__l * self.__w
    
    def perim(self):
        return 2 * (self.__l + self.__w)

    # point identfication/parameterization
    def points(self, n=16):
        n = min(16, max(1, int(n)))
        pts = []

        x0 = self.get_x()
        y0 = self.get_y()
        l = self.__l
        w = self.__w

        side = max(1, n // 4)

        # bottom
        for i in range(side):
            t = i / side
            pts.append((x0 + t * l, y0))

        # right
        for i in range(side):
            t = i / side
            pts.append((x0 + l, y0 + t * w))

        # top
        for i in range(side):
            t = i / side
            pts.append((x0 + l - t * l, y0 + w))

        # left
        for i in range(side):
            t = i / side
            pts.append((x0, y0 + w - t * w))

        return pts[:n]

    # checking inside for rectangle
    def inside(self, x, y):
        x0 = self.get_x()
        y0 = self.get_y()

        # basic logic for checking bounds
        if x < x0:
            return False
        if x > x0 + self.__l:
            return False
        if y < y0:
            return False
        if y > y0 + self.__w:
            return False

        return True

    def paint(self, canvas):
        x0 = int(self.get_x())
        y0 = int(self.get_y())
        l = int(self.__l)
        w = int(self.__w)

        canvas.v_line(x0, y0, l + 1)
        canvas.v_line(x0, y0 + w, l + 1)
        canvas.h_line(x0, y0, w + 1)
        canvas.h_line(x0 + l, y0, w + 1)

    # accessors
    def get_l(self):
        return self.__l

    def get_w(self):
        return self.__w


class circle(shape):
    def __init__(self, r, x, y):
        shape.__init__(self, x, y)
        self.__r = r
        self.__pi = math.pi

    def area(self):
        return self.__pi * (self.__r ** 2)

    def perim(self):
        return 2 * self.__pi * self.__r

    def points(self, n=16):
        n = min(16, max(1, int(n)))
        pts = []

        center_x = self.get_x()
        center_y = self.get_y()
        r = self.__r

        for i in range(n):
            t = 2 * math.pi * i / n
            pts.append((center_x + r * math.cos(t), center_y + r * math.sin(t)))

        return pts

    # checking inside for circle
    def inside(self, x, y):
        center_x = self.get_x()
        center_y = self.get_y()
    
        dx = x - center_x
        dy = y - center_y
    
        dist = math.sqrt(dx*dx + dy*dy)
        return dist <= self.__r

    # paint circle using sampled perimeter points
    def paint(self, canvas):
        pts = self.points(16)
        for p in pts:
            canvas.set_pixel(int(p[0]), int(p[1]))

    # accessor
    def get_r(self):
        return self.__r


class triangle(shape):
    # x and y points are at the first vertex
    def __init__(self, a, b, c, x, y):
        shape.__init__(self, x, y)
        self.__a = a
        self.__b = b
        self.__c = c

    def perim(self):
        return self.__a + self.__b + self.__c

    def area(self):
        s = self.perim() / 2
        return (s * (s - self.__a) * (s - self.__b) * (s - self.__c)) ** 0.5

    def points(self, n=16):
        n = min(16, max(1, int(n)))
        pts = []

        x1 = self.get_x()
        y1 = self.get_y()

        a = self.__a
        b = self.__b
        c = self.__c

        # validity check (basic)
        if a <= 0 or b <= 0 or c <= 0:
            return pts
        if a + b <= c or a + c <= b or b + c <= a:
            return pts

        # v2
        x2 = x1 + a
        y2 = y1

        # v3
        x3 = x1 + (b*b + a*a - c*c) / (2*a)
        y_sq = b*b - (x3 - x1)**2
        if y_sq < 0:
            return pts
        y3 = y1 + (y_sq ** 0.5)

        def line_points(xA, yA, xB, yB, count):
            out = []
            for i in range(count):
                t = i / count
                out.append((xA + t * (xB - xA), yA + t * (yB - yA)))
            return out

        base = n // 3
        rem = n % 3

        n1 = base + (1 if rem > 0 else 0)
        n2 = base + (1 if rem > 1 else 0)
        n3 = base

        pts += line_points(x1, y1, x2, y2, max(1, n1))
        pts += line_points(x2, y2, x3, y3, max(1, n2))
        pts += line_points(x3, y3, x1, y1, max(1, n3))

        return pts[:n]

    # inside check for triangle w/area method
    def inside(self, x, y):
        x1 = self.get_x()
        y1 = self.get_y()

        a = self.__a
        b = self.__b
        c = self.__c

        # invalid triangle check
        if a <= 0 or b <= 0 or c <= 0:
            return False
        if a + b <= c or a + c <= b or b + c <= a:
            return False

        # v2
        x2 = x1 + a
        y2 = y1

        # v3
        x3 = x1 + (b*b + a*a - c*c) / (2*a)
        y_sq = b*b - (x3 - x1)**2
        if y_sq < 0:
            return False
        y3 = y1 + (y_sq ** 0.5)

        def tri_area(xa, ya, xb, yb, xc, yc):
            return abs(xa*(yb-yc) + xb*(yc-ya) + xc*(ya-yb)) / 2

        full = tri_area(x1, y1, x2, y2, x3, y3)
        a1 = tri_area(x, y, x2, y2, x3, y3)
        a2 = tri_area(x1, y1, x, y, x3, y3)
        a3 = tri_area(x1, y1, x2, y2, x, y)

        return abs((a1 + a2 + a3) - full) < 1e-6

    # paint function I got to work w vertical lines
    def paint(self, canvas):
        x1 = self.get_x()
        y1 = self.get_y()
    
        a = self.__a
        b = self.__b
        c = self.__c
    
        # validity check
        if a <= 0 or b <= 0 or c <= 0:
            return
        if a + b <= c or a + c <= b or b + c <= a:
            return
    
        # compute vertices
        x2 = x1 + a
        y2 = y1
    
        x3 = x1 + (b*b + a*a - c*c) / (2*a)
        y_sq = b*b - (x3 - x1)**2
        if y_sq < 0:
            return
        y3 = y1 + (y_sq ** 0.5)
    
        def draw_edge(xA, yA, xB, yB):
            dx = xB - xA
            dy = yB - yA
            steps = int(max(abs(dx), abs(dy), 1))
        
            for i in range(steps + 1):
                t = i / steps
                x = int(xA + t * dx)
                y = int(yA + t * dy)
        
                # bounds check (Canvas.set_pixel has none)
                if 0 <= x < canvas.height and 0 <= y < canvas.width:
                    canvas.set_pixel(x, y)
    
        draw_edge(x1, y1, x2, y2)
        draw_edge(x2, y2, x3, y3)
        draw_edge(x3, y3, x1, y1)

    # accessors
    def get_a(self):
        return self.__a

    def get_b(self):
        return self.__b

    def get_c(self):
        return self.__c 


# CompoundShape class
class CompoundShape(shape):
    def __init__(self, shapes):
        shape.__init__(self, 0, 0)
        self.shapes = shapes

    def paint(self, canvas):
        for s in self.shapes:
            s.paint(canvas)

# %%
# testing triangle display
cv = Canvas(40, 15)

t = triangle(8, 7, 5, 2, 2)
t.paint(cv)

cv.display()
# Out:
#
#
#   *
#   *
#   **
#   * *
#   *  *
#   *   *
#   * **
#   **
#   *

# %%
# I had ChatGPT generate a tester w the format I had already been running, below is the result.
# Biggest thing was the tirangle generation, now it seems that it reliably outputs
# next step will be utlizing the module

# =========================
# OVERALL TESTER (Q10)
# Tests:
#   - area/perim
#   - points() + inside()
#   - overlap()
#   - paint() for rectangle/circle/triangle
#   - CompoundShape paint()
# =========================

# ---- create shapes ----
r = rectangle(10, 5, 2, 2)
c = circle(4, 8, 30)
t = triangle(8, 7, 5, 12, 5)

print("=== area/perim ===")
print("rect:", r.area(), r.perim())
print("circ:", round(c.area(), 3), round(c.perim(), 3))
print("tri :", t.area(), t.perim())

print("\n=== points count (<=16) ===")
print("rect pts:", len(r.points()))
print("circ pts:", len(c.points()))
print("tri  pts:", len(t.points()))

print("\n=== inside tests (one inside, one outside) ===")
print("rect:", r.inside(3, 3), r.inside(0, 0))
print("circ:", c.inside(8, 30), c.inside(0, 0))
print("tri :", t.inside(13, 5), t.inside(0, 0))

print("\n=== overlap tests ===")
r2 = rectangle(3, 3, 5, 4)      # overlaps r
r3 = rectangle(2, 2, 50, 50)    # far away
print("r vs r2:", r.overlap(r2))
print("r vs r3:", r.overlap(r3))
print("r vs c :", r.overlap(c))
print("t vs r :", t.overlap(r))

print("\n=== paint test (individual) ===")
cv1 = Canvas(60, 20)
r.paint(cv1)
c.paint(cv1)
t.paint(cv1)
cv1.display()

print("\n=== paint test (CompoundShape) ===")
cv2 = Canvas(60, 20)
combo = CompoundShape([r, c, t, r2])
combo.paint(cv2)
cv2.display()
# Out:
# === area/perim ===
# rect: 50 30
# circ: 50.265 25.133
# tri : 17.320508075688775 20
#
# === points count (<=16) ===
# rect pts: 16
# circ pts: 16
# tri  pts: 16
#
# === inside tests (one inside, one outside) ===
# rect: True False
# circ: True False
# tri : True False
#
# === overlap tests ===
# r vs r2: True
# r vs r3: False
# r vs c : False
# t vs r : True
#
# === paint test (individual) ===
#
#
#   ******
#   *    *
#   *    *                    * **
#   *    *                   *    *
#   *    *                  *      *
#   *    *                  *
#   *    *                          *
#   *    *                  *      *
#   *    *                   *    *
#   *    *                    *  *
#   ******                      *
#      *
#      **
#      * *
#      *  *
#      *   *
#      * **
#      **
#
# === paint test (CompoundShape) ===
#
#
#   ******
#   *    *
#   *    *                    * **
#   * ****                   *    *
#   * *  *                  *      *
# ...

# %%
# Actual implementation
# kind of a mess visually, but it works

import paint

cv = paint.Canvas(80, 25)

shapes = [
    paint.rectangle(12, 6, 2, 2),
    paint.rectangle(8, 4, 10, 40),
    paint.circle(5, 10, 20),
    paint.circle(3, 15, 60),
    paint.triangle(10, 9, 7, 5, 5),
    paint.triangle(8, 7, 6, 12, 30)
]

scene = paint.CompoundShape(shapes)
scene.paint(cv)
cv.display()
# Out:
#
#
#   *******
#   *     *
#   *     *
#   *  *  *         * **
#   *  ** *       *      *
#   *  * **
#   *  *  *      *        *
#   *  *  **     *
#   *  *  * *              *              *****
#   *  *  *  *   *        *               *   *
#   *  *  ***                   **        *   *            ** ***
#   *  * **       *      *      * *       *   *            *    *
#   *******         *  *        *  *      *   *
#      *              *         *   *     *   *            *     *
#                               *    *    *   *            *    *
#                               *   *     *   *            **  **
#                               * **      *****               *
#                               **
#                               *

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
# Straight ffrom lecture 9

# class RasterDrawing:
#     def __init__(self):
#         self.shapes=dict()
#         self.shape_names=list()
#         
#     def add_shape(self,shape):
#         if shape.name == "":
#             shape.name = self.assign_name()
#         
#         self.shapes[shape.name]=shape
#         self.shape_names.append(shape.name)
#
#     def update(self, canvas):
#         canvas.clear_canvas()
#         self.paint(canvas)
#         
#     def paint(self,canvas):
#         for shape_name in self.shape_names:
#             self.shapes[shape_name].paint(canvas)
#             
#     def assign_name(self):
#         name_base="shape"
#         name = name_base+"_0"
#         
#         i=1
#         while name in self.shapes:
#             name = name_base+"_"+str(i)
#             
#         return name

class RasterDrawing:
    def __init__(self):
        self.shapes = dict()
        self.shape_names = list()

    def assign_name(self):
        name_base = "shape"
        i = 0
        name = name_base + "_" + str(i)

        while name in self.shapes:
            i += 1
            name = name_base + "_" + str(i)

        return name

    def add_shape(self, shp):
        if not hasattr(shp, "name"):
            shp.name = ""

        if shp.name == "":
            shp.name = self.assign_name()

        self.shapes[shp.name] = shp

        # keep paint order
        if shp.name not in self.shape_names:
            self.shape_names.append(shp.name)

    def paint(self, canvas):
        for shape_name in self.shape_names:
            self.shapes[shape_name].paint(canvas)

    def update(self, canvas):
        canvas.clear_canvas()
        self.paint(canvas)

# lil different order but generally follows what was in Lecture 9

# %%
import paint

cv = paint.Canvas(60, 20)
rd = RasterDrawing()

r = paint.rectangle(10, 5, 2, 2); r.name = "rect"
c = paint.circle(4, 8, 30);       c.name = "circ"
t = paint.triangle(8, 7, 5, 12, 5);t.name = "tri"

rd.add_shape(r)
rd.add_shape(c)
rd.add_shape(t)

print("first paint")
rd.update(cv)
cv.display()

# modify drawing (replace shapes in dict, lecture-style)
rd.shapes["rect"] = paint.rectangle(16, 7, 2, 2)
rd.shapes["circ"] = paint.circle(2, 6, 40)

print("after modification")
rd.update(cv)
cv.display()

# this art is still better than some modern art, kinda sad really
# Out:
# first paint
#
#
#   ******
#   *    *
#   *    *                    * **
#   *    *                   *    *
#   *    *                  *      *
#   *    *                  *
#   *    *                          *
#   *    *                  *      *
#   *    *                   *    *
#   *    *                    *  *
#   ******                      *
#      *
#      **
#      * *
#      *  *
#      *   *
#      * **
#      **
# after modification
#
#
#   ********
#   *      *
#   *      *                            ****
#   *      *                            *  *
#   *      *                            *  **
#   *      *                            ****
#   *      *                              *
#   *      *
#   *      *
#   *      *
#   *  *   *
#   *  *   *
#   *  **  *
#   *  * * *
#   *  *  **
#   *  *   *
#   ********
#      **

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')

# %%
# the final shebang

# note, the __repr__ was added to paint.py and RasterDrawing now is housed in paint.py too

import paint

c1 = paint.Canvas(40, 20)
rd1 = paint.RasterDrawing()

rd1.add_shape(paint.rectangle(10, 6, 2, 2))
rd1.add_shape(paint.circle(5, 12, 25))
rd1.add_shape(paint.triangle(10, 9, 7, 8, 5))

rd1.update(c1)
s1 = "\n".join(["".join(row) for row in c1.data])

rd1.save("drawing.txt")

rd2 = paint.raster_loader("drawing.txt")

c2 = paint.Canvas(40, 20)
rd2.update(c2)
s2 = "\n".join(["".join(row) for row in c2.data])

print(s1 == s2)
c2.display()
# Out:
# True
#
#
#   *******
#   *     *
#   *     *
#   *     *
#   *     *
#   *     *              * **
#   *  *  *            *      *
#   *  ** *
#   *  * **           *        *
#   *  *  *           *
#   ********                    *
#      *    *         *        *
#      *     *
#      *   **          *      *
#      * **              *  *
#      **                  *
#      *
